# %%
import pandas as pd

# %%
import json
import requests


ENRICHR_URL = 'http://maayanlab.cloud/Enrichr/addList'
genes_str = '\n'.join([
    'PHF14', 'RBM3', 'MSL1', 'PHF21A', 'ARL10', 'INSR', 'JADE2', 'P2RX7',
    'LINC00662', 'CCDC101', 'PPM1B', 'KANSL1L', 'CRYZL1', 'ANAPC16', 'TMCC1',
    'CDH8', 'RBM11', 'CNPY2', 'HSPA1L', 'CUL2', 'PLBD2', 'LARP7', 'TECPR2', 
    'ZNF302', 'CUX1', 'MOB2', 'CYTH2', 'SEC22C', 'EIF4E3', 'ROBO2',
    'ADAMTS9-AS2', 'CXXC1', 'LINC01314', 'ATF7', 'ATP5F1'
])
description = 'Example gene list'
payload = {
    'list': (None, genes_str),
    'description': (None, description)
}

response = requests.post(ENRICHR_URL, files=payload)
if not response.ok:
    raise Exception('Error analyzing gene list')

data = json.loads(response.text)
print(data)
# Out:
# {'shortId': 'fbfdfe41873bb0ebce364943750531db', 'userListId': 36253362}

# %%
ENRICHR_URL = 'http://maayanlab.cloud/Enrichr/view?userListId=%s'
user_list_id = 36253362
response = requests.get(ENRICHR_URL % user_list_id)
if not response.ok:
    raise Exception('Error getting gene list')
    
data = json.loads(response.text)
print(data)
# Out:
# {'genes': ['INSR', 'ARL10', 'HSPA1L', 'CNPY2', 'ATP5F1', 'LARP7', 'MSL1', 'P2RX7', 'PPM1B', 'TMCC1', 'MOB2', 'CRYZL1', 'PHF14', 'PLBD2', 'EIF4E3', 'SEC22C', 'ATF7', 'TECPR2', 'LINC01314', 'CCDC101', 'ANAPC16', 'LINC00662', 'CUL2', 'JADE2', 'CXXC1', 'ADAMTS9-AS2', 'PHF21A', 'ROBO2', 'CDH8', 'RBM3', 'CUX1', 'KANSL1L', 'ZNF302', 'CYTH2', 'RBM11'], 'description': 'Example gene list'}

# %%
ENRICHR_URL = 'http://maayanlab.cloud/Enrichr/enrich'
query_string = '?userListId=%s&backgroundType=%s'
user_list_id = 36253362
gene_set_library = 'KEGG_2015'
response = requests.get(
    ENRICHR_URL + query_string % (user_list_id, gene_set_library)
 )
if not response.ok:
    raise Exception('Error fetching enrichment results')

data = json.loads(response.text)
print(data)
# Out:
# {'KEGG_2015': [[1, 'dentatorubropallidoluysian atrophy', 0.025939658708656763, 41.91386554621849, 153.06869330263612, ['INSR'], 0.23664536594667288, 0, 0], [2, 'ubiquitin mediated proteolysis', 0.06608937289376358, 15.423374613003096, 41.901411617706714, ['CUL2'], 0.23664536594667288, 0, 0], [3, 'type ii diabetes mellitus', 0.07099360978400186, 14.292682926829269, 37.8065104803334, ['INSR'], 0.23664536594667288, 0, 0], [4, 'renal cell carcinoma', 0.11402053165072557, 8.605968858131488, 18.686800643339396, ['CUL2'], 0.24663156392022864, 0, 0], [5, 'adherens junction', 0.12331578196011432, 7.905802861685214, 16.546899785939424, ['INSR'], 0.24663156392022864, 0, 0], [6, 'axon guidance', 0.19859256680350648, 4.668235294117647, 7.546202147771418, ['ROBO2'], 0.28370366686215215, 0, 0], [7, 'oxidative phosphorylation', 0.19859256680350648, 4.668235294117647, 7.546202147771418, ['ATP5F1'], 0.28370366686215215, 0, 0], [8, 'calcium signaling pathway', 0.25714901264766904, 3.465861344537815, 4.70698471978231, ['P2RX7'], 0.3214362658095863, 0, 0], [9, 'neuroactive ligand receptor interaction', 0.3425298305903255, 2.4482501861504096, 2.623046750239322, ['P2RX7'], 0.35408435074596933, 0, 0], [10, 'mapk signaling pathway', 0.35408435074596933, 2.3479399857108834, 2.4376785226560895, ['PPM1B'], 0.35408435074596933, 0, 0]]}

# %%
ENRICHR_URL = 'http://maayanlab.cloud/Enrichr/genemap'
query_string = '?json=true&setup=true&gene=%s'
gene = 'AKT1'
response = requests.get(ENRICHR_URL + query_string % gene)
if not response.ok:
    raise Exception('Error searching for terms')
    
data = json.loads(response.text)
print(data)
# Out:
# {'gene': {'GeneSigDB': ['18535662-TableS2b', '17671232-TableS2a', '17213801-RADinsensitive', '17177833-SuppTable1', '16740760-TableS2a', '15467184-Table1b', '15705876-TableS6', '16740760-TableS2b', '20521089-SuppTable1a', '19341462-SuppTable2', '17571080-SuppTable2b', '20460173-ImmPortTCRSignalingPathway', '19129520-TableS27', '17683608-TableS3', '19597962-Table3', '16081686-SuppTable4', '12509443-Table2', '16872506-SuppTable1', '16651414-Supp4', '19074878-SuppTable2', '18160665-TableS5', '16207381-Table1Sb', '15897907-SuppTable2', '16705456-Table2', '20460173-ImmPortComprehensiveListofImmune-RelatedGenes', '19408105-SuppTable4', '16273092-TableS1b', '19808870-ST1', '20460173-ImmPortBCRSignalingPathway', '15735024-SuppTable2', '12471243-TableS2', '17804543-Table2', '16740760-TableS1', '19904269-ST1', '11375906-table1', '17122647-Table3'], 'MSigDB_Hallmark_2020': ['Androgen Response', 'PI3K/AKT/mTOR  Signaling', 'Allograft Rejection'], 'Enrichr_Submissions_TF-Gene_Coocurrence': ['ARGFX', 'ARNT', 'ATF2', 'CENPB', 'CIC', 'CIZ1', 'CREB1', 'CXXC1', 'DEAF1', 'DVL1', 'DVL2', 'DVL3', 'E2F4', 'ESR1', 'ESR2', 'FOXK2', 'GATAD2A', 'HMG20B', 'IRF3', 'KAT5', 'MAX', 'MAZ', 'MBD1', 'MECP2', 'MLLT1', 'MTA1', 'MYC', 'MYOD1', 'NCOR1', 'NCOR2', 'NFKB1', 'NR1H2', 'NR2F6', 'NR5A1', 'RARA', 'RELA', 'RXRB', 'SMAD2', 'SMAD3', 'SMAD4', 'SP1', 'SREBF2', 'SRF', 'STAT3', 'STAT5B', 'STAT6', 'TCF3', 'THRA', 'TP53', 'TP73', 'USF2', 'YY1', 'ZBTB17', 'ZBTB22', 'ZNF282', 'ZNF444', 'ZNF74'], 'SysMyo_Muscle_Gene_Sets': ['MGS242 C2c12 myotube d4 diff v d3 diff GSE4330 down', 'MGS244 C2c12 myotube d5 diff v d3 diff GSE4330 down', 'MGS246 C2c12 myotube d6 diff v d3 diff GSE4330 down', 'MGS256 Murine prim myotube pRb null v normal GSE10428 down', 'MGS292 C2c12 myoblast overexpression miR145 v control GSE26764 down', 'MGS544 Human mixed sex deltoid muscle v heart GSE7307 down', 'MGS747 Murine age12wk heart Pitx2 KO v WT GSE50399 up', 'MGS897 Murine age6wk TA denervated Runx1 KO v WT GSE4411 up', 'MGS948 Murine age8wk heart isoproterenol induced cardiomyopathy v control GSE18801 down', 'MGS1050 Murine C2C12 myotube 3h diff cycloheximide pretreated v WT GSE16992 down', 'MGS1151 Murine PGC1a KO TA and EDL muscles calorie restricted diet v control GSE34773 up', 'MGS1226 Murine age9to12wk heart oral dose fatty acid trilinolein v control GSE30495 down', 'MGS1228 Murine age9to12wk heart oral dose fatty acid trilinolenin v control GSE30495 down', 'MGS1396 Murine muscle 2d post treatment TLR4 agonist SE v control PBS treated GSE43373 down', 'MGS1442 Murine quad STAT5ab KO v WT GSE14710 down', 'MGS1494 Murine soleus mir 206 133b KO v WT E-MTAB-2439 down', 'MGS1504 Murine ventricle transverse aortic constriction Gata4 heterozygotes v WT GSE5500 down'], 'BioPlanet_2019': ['AKT phosphorylation of cytosolic targets', 'AKT phosphorylation of nuclear targets', 'AKT signaling pathway', 'AMPK signaling', 'Actions of nitric oxide in the heart', 'Activation of BH3-only proteins', 'Acute myeloid leukemia', 'Adaptive immune system', 'Adipocytokine signaling pathway', 'Adrenergic pathway', 'Alpha-6 beta-1 and alpha-6 beta-4 integrin signaling', 'Alpha-6 beta-4 integrin signaling pathway', 'Alpha-M beta-2 integrin signaling', 'Androgen receptor proteolysis and transcription regulation', 'Androgen receptor signaling, proteolysis, and transcription regulation', 'Angiogenesis', 'Angiopoietin receptor Tie2-mediated signaling', 'Antigen-activated B-cell receptor generation of second messengers', 'Apoptosis', 'Apoptosis intrinsic pathway', 'Apoptotic signaling in response to DNA damage', 'B cell survival pathway', 'BAD activation and translocation to mitochondria', 'BAD phosphorylation mediated by IGF1R signaling', 'BAD phosphorylation regulation', 'CD28 co-stimulation', 'CD28-dependent PI3K/Akt signaling', 'CD40/CD40L signaling', 'CREB transcription factor and its extracellular signals', 'CTLA4 inhibitory signaling', 'CXCR4 signaling pathway', 'Caspase cascade in apoptosis', 'Cell differentiation ...

# %%
class Enrich:
    
    
    
    def __init__(self, gene_list, threshold):
        self.gene_list = gene_list
        self.threshold = threshold
        
    def analyze_gene_list(self):
        
        ENRICHR_URL = 'http://maayanlab.cloud/Enrichr/addList'
        genes_str = '\n'.join(self.gene_list)
        description = 'Example gene list'
        payload = {
                    'list': (None, genes_str),
                    'description': (None, description)
                    }

        response = requests.post(ENRICHR_URL, files=payload)
        if not response.ok:
            raise Exception('Error analyzing gene list')

        dict_results = json.loads(response.text)
        return dict_results['userListId']
    
    def get_enrichment_results(self):
        
        ENRICHR_URL = 'http://maayanlab.cloud/Enrichr/enrich'
        query_string = '?userListId=%s&backgroundType=%s'
        user_list_id = self.analyze_gene_list()
        gene_set_library = 'KEGG_2015'
        response = requests.get(
            ENRICHR_URL + query_string % (user_list_id, gene_set_library)
         )
        if not response.ok:
            raise Exception('Error fetching enrichment results')

        dict_results = json.loads(response.text)
        list_results = [i[1] for i in  dict_results['KEGG_2015'] if i[4] >= self.threshold]
        return list_results

# %%
s_g = [
    'PHF14', 'RBM3', 'MSL1', 'PHF21A', 'ARL10', 'INSR', 'JADE2', 'P2RX7',
    'LINC00662', 'CCDC101', 'PPM1B', 'KANSL1L', 'CRYZL1', 'ANAPC16', 'TMCC1',
    'CDH8', 'RBM11', 'CNPY2', 'HSPA1L', 'CUL2', 'PLBD2', 'LARP7', 'TECPR2', 
    'ZNF302', 'CUX1', 'MOB2', 'CYTH2', 'SEC22C', 'EIF4E3', 'ROBO2',
    'ADAMTS9-AS2', 'CXXC1', 'LINC01314', 'ATF7', 'ATP5F1'
]
g = Enrich(s_g, 100)

# %%
print(g.get_enrichment_results())
# Out:
# ['dentatorubropallidoluysian atrophy']

# %%
type(g.analyze_gene_list())
# Out:
# int
